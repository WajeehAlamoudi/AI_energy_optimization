# %% [markdown]
# ## build_device_catalog.ipynb

# %%
import pandas as pd
import json
from pathlib import Path

raw_path = Path("raw_data/smart_home_energy_consumption_large.csv")
output_path = Path("data/devices_catalog.json")

# %%
df = pd.read_csv(raw_path)
print(df.shape)
df.head(50)
# Out:
# (100000, 8)
#     Home ID    Appliance Type  Energy Consumption (kWh)   Time        Date  \
# 0        94            Fridge                      0.20  21:12  2023-12-02
# 1       435              Oven                      0.23  20:11  2023-08-06
# 2       466        Dishwasher                      0.32  06:39  2023-11-21
# 3       496            Heater                      3.92  21:56  2023-01-21
# 4       137         Microwave                      0.44  04:31  2023-08-26
# 5        68  Air Conditioning                      4.68  11:36  2023-05-06
# 6       237          Computer                      0.25  12:05  2023-06-06
# 7       329  Air Conditioning                      3.50  03:34  2023-12-12
# 8       336        Dishwasher                      0.89  15:22  2023-08-16
# 9       310         Microwave                      1.34  16:32  2023-09-19
# 10      368              Oven                      0.64  11:19  2023-10-19
# 11      115        Dishwasher                      1.33  17:51  2023-05-17
# 12       41         Microwave                      0.85  19:53  2023-02-21
# 13      465              Oven                      1.24  13:29  2023-11-17
# 14       94  Air Conditioning                      2.88  00:13  2023-05-15
# 15      229            Heater                      4.11  00:57  2023-04-26
# 16      360            Fridge                      0.12  08:40  2023-10-24
# 17       71                TV                      1.65  04:16  2023-08-09
# 18      352        Dishwasher                      1.62  17:18  2023-12-20
# 19      445        Dishwasher                      1.33  04:17  2023-10-30
# 20      257          Computer                      0.35  19:46  2023-11-24
# 21      133   Washing Machine                      1.09  04:45  2023-10-23
# 22      372  Air Conditioning                      3.05  19:43  2023-10-16
# 23      253            Heater                      4.87  05:09  2023-09-05
# 24       59            Lights                      1.02  03:42  2023-12-22
# 25      419              Oven                      0.65  02:57  2023-01-12
# 26      466            Heater                      2.03  16:04  2023-06-05
# 27      281              Oven                      0.28  08:40  2023-03-25
# 28      257  Air Conditioning                      4.84  10:06  2023-11-20
# 29      120              Oven                      0.38  19:45  2023-03-02
# 30      343   Washing Machine                      1.17  15:54  2023-07-08
# 31      157         Microwave                      0.30  15:19  2023-10-13
# 32      242            Lights                      1.36  14:42  2023-09-30
# 33      321        Dishwasher                      1.55  16:11  2023-12-19
# 34       19                TV                      0.65  05:36  2023-10-31
# 35      114                TV                      0.47  23:43  2023-09-04
# 36      405          Computer                      1.53  14:09  2023-07-29
# 37      470              Oven                      0.73  17:24  2023-03-19
# 38      484            Heater                      2.88  01:50  2023-05-31
# 39      368          Computer                      0.93  12:39  2023-06-01
# 40      414                TV                      1.63  15:29  2023-01-23
# 41      383          Computer                      0.79  08:12  2023-03-03
# 42       68         Microwave                      1.01  12:52  2023-11-08
# 43       50            Heater                      2.54  07:43  2023-08-31
# 44      156              Oven                      1.33  14:17  2023-05-05
# 45       10            Lights                      1.63  22:22  2023-07-28
# 46      209              Oven                      0.38  19:51  2023-03-07
# 47      102              Oven                      1.88  01:26  2023-03-22
# 48      212                TV                      1.34  06:06  2023-11-25
# 49      214  Air Conditioning                      3.44  10:02  2023-06-30
#
#     Outdoor Temperature (°C)  Season  Household Size
# 0                       -1.0    Fall               2
# 1                       31.1  Summer               5
# 2                       21.3    Fall               3
# 3                       -4.2  Winter               1
# 4                       34.5  Summer               5
# 5                       35.2  Spring               1
# 6                        6.8  Spring               3
# 7                       -1.0    Fall               4
# 8                        7.9  Summer               1
# 9                        9.3  Summer               5
# 10                      -7.3    Fall               3
# 11                      39.0  Spring               2
# 12                      -7.4  Winter               3
# 13                      20.3    Fall               5
# 14                       2.1  Spring               1
# 15                      -0.3  Spring               2
# 16                      39.8    Fall               2
# 17                       3.0  Summer               4
# 18                      16.3    Fall               4
# 19                      30.9    Fall               5
# 20                      12.4    Fall               5
# 21                       6.5    Fall               3
# 22                      30.6    Fall               4
# 23                      29.0  Summer               2
# 24                       1.1    Fall               3
# 25                       5.3  Winter               4
# 26                      15.3  Spring               5
# 27                      19.0  Winter               5
# 28                      -8.0    Fall               4
# 29                      24.6  Winter               4
# 30                      10.9  Summer               4
# 31                      23.6    Fall               2
# 32                      39.6  Summer               4
# 33                       1.3    Fall               1
# 34                      20.3    Fall               4
# 35                      15.7  Summer               2
# 36                      37.2  Summer               4
# 37                      19.5  Winter               1
# 38                      21.7  Spring               4
# 39                      21.6  Spring               4
# 40                      36.6  Winter               4
# 41                      17.3  Winter               5
# 42                      -0.4    Fall               1
# 43                      -2.4  Summer               4
# 44                      -4.3  Spring               1
# 45                      26.9  Summer               2
# 46                      32.3  Winter               4
# 47                      37.5  Winter               3
# 48                      25.4    Fall               1
# 49                      34.6  Spring               4

# %%
df.columns = df.columns.str.strip().str.replace(" ", "_").str.lower()
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100000 entries, 0 to 99999
# Data columns (total 8 columns):
#  #   Column                    Non-Null Count   Dtype
# ---  ------                    --------------   -----
#  0   home_id                   100000 non-null  int64
#  1   appliance_type            100000 non-null  object
#  2   energy_consumption_(kwh)  100000 non-null  float64
#  3   time                      100000 non-null  object
#  4   date                      100000 non-null  object
#  5   outdoor_temperature_(°c)  100000 non-null  float64
#  6   season                    100000 non-null  object
#  7   household_size            100000 non-null  int64
# dtypes: float64(2), int64(2), object(4)
# memory usage: 6.1+ MB

# %%
# Drop any rows missing device or kWh values
df = df.dropna(subset=["appliance_type", "energy_consumption_(kwh)"])

# Make sure numeric columns are correct types
df["energy_consumption_(kwh)"] = pd.to_numeric(df["energy_consumption_(kwh)"], errors="coerce")

# Remove any remaining NaN
df = df.dropna(subset=["energy_consumption_(kwh)"])

# %%
summary = (
    df.groupby("appliance_type")["energy_consumption_(kwh)"]
      .mean()
      .reset_index()
      .sort_values("energy_consumption_(kwh)", ascending=False)
      .rename(columns={
          "appliance_type": "device",
          "energy_consumption_(kwh)": "avg_kwh"
      })
)

summary.head(100)
# Out:
#              device   avg_kwh
# 0  Air Conditioning  3.499857
# 4            Heater  3.486802
# 2        Dishwasher  1.103369
# 7              Oven  1.103080
# 9   Washing Machine  1.101412
# 6         Microwave  1.100961
# 8                TV  1.097221
# 1          Computer  1.095498
# 5            Lights  1.087356
# 3            Fridge  0.298255

# %%
catalog = {}
for _, row in summary.iterrows():
    name = row["device"].strip().title()  # clean capitalization
    base_kwh = round(float(row["avg_kwh"]), 3)
    catalog[name] = {
        "base_kWh": base_kwh,
        "permissions": []
    }

# %%
with open(output_path, "w", encoding="utf-8") as f:
    json.dump(catalog, f, indent=2, ensure_ascii=False)

print(f"✅ Exported {len(catalog)} devices to {output_path}")
# Out:
# ✅ Exported 10 devices to data\devices_catalog.json
